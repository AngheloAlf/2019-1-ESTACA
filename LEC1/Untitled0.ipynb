# %%
print("Hola, Merak!")
import seaborn as sns
import pandas as pd
# Out:
# Hola, Merak!

# %%
# !pip install -q Timestamp

# %%
# Para subir los csv
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-039c3428-11e6-422a-bcab-13e530e2301a" name="files[]" multiple disabled />
#      <output id="result-039c3428-11e6-422a-bcab-13e530e2301a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving athlete_events.csv to athlete_events (1).csv

# %%
region = pd.read_csv("noc_regions.csv")

athlete = pd.read_csv("athlete_events.csv")

union = pd.merge(athlete, region, on="NOC", how="left")
print(union)
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 9            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 10           6                     Per Knut Aaland   M  31.0   188.0    75.0
# ...

# %%
sns.factorplot("colors", data=union , palette="PuBu_d");  #grafico de barras
from seaborn import lmplot

lmplot('total_bill', 'tip', data=tips, fit_reg=False) #scatterplotor=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, notch=False, ax=None, **kwargs) #boxplot
# https://seaborn.pydata.org/generated/seaborn.boxplot.html
# https://www.analyticslane.com/2018/07/20/visualizacion-de-datos-con-seaborn/

seaborn.boxplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, col
# Out:
#   File "<ipython-input-6-28181bd27523>", line 8
#     seaborn.boxplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, col
#                                                                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
PartPorPais = union.region.value_counts().reset_index(name='Participantes').head(10)

g = sns.factorplot("index", "Participantes", data=PartPorPais, kind="bar", palette="muted", legend=True)
g.set(xlabel='Pais', ylabel='Participantes')
g.set_xticklabels(rotation=60)

PartPorCateg =  union.Sport.value_counts().reset_index(name='Participantes').head(10)

g = sns.factorplot("index", "Participantes", data=PartPorCateg, kind="bar", palette="muted", legend=True)
g.set(xlabel='Categoria de deporte', ylabel='Participantes')
g.set_xticklabels(rotation=60)

# %%
basket = union[(union.Sport == 'Basketball')]

g3 = sns.boxplot(x = "Height", data=basket)

# %%
# print(union.count())
ax = sns.scatterplot(x="Sport", y="Age", hue="region",data=union)

# %%
# sns.lineplot(x="Year", y="signal", hue="label", data=union)

# union.Year.value_counts().reset_index(name='Sex')
# union.sort_values(['Year'])
# print(union)
# sns.lineplot(x="Year", y="region", hue="Sex", data=union)
# sns.catplot(x="Year", hue="Sex",kind="violin", split=True, data=union);
sns.catplot(x="Year", hue="Sex",kind="point", data=union);
# print(union[(union.Sex != "M") & (union.Sex != "F")])
# sns.catplot(x="Year", hue="Sex",
            # palette={"M": "g", "F": "m"},
            # markers=["^", "o"], linestyles=["-", "--"],
            # kind="point", data=union);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-80bb95f32d54> in <module>
#       7 # sns.lineplot(x="Year", y="region", hue="Sex", data=union)
#       8 # sns.catplot(x="Year", hue="Sex",kind="violin", split=True, data=union);
# ----> 9 sns.catplot(x="Year", hue="Sex",kind="point", data=union);
#      10 # print(union[(union.Sex != "M") & (union.Sex != "F")])
#      11 # sns.catplot(x="Year", hue="Sex",
#
# ~/.local/lib/python3.5/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3763
#    3764     if legend and (hue is not None) and (hue not in [x, row, col]):
# -> 3765         hue_order = list(map(utils.to_utf8, hue_order))
# ...
